# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp
import pdb
import copy
from scipy import sparse
import anndata
import cerberus


p = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
h5 = '../cerberus/cerberus_annot.h5'
h5_trip = 'cerberus_annot_triplets.h5'
ab = '../talon/mouse_talon_abundance.tsv'
filt_ab = '../cerberus/cerberus_filtered_abundance.tsv'
obs_col = 'sample'
species='mouse'
min_tpm = 1
major_set = '../swan/isos_sample_gene_90.tsv'
gene_subset = 'polya'

# %%
ca = cerberus.read(h5_trip)

# %%
# HOX genes
temp = ca.plot_simplex(top='splicing_ratio',
            subset={'source': 'sample_det', 'hox_gene': True},
            density=True,
            density_scale=20,
            density_cmap='Purples',
            log_density=True,
            sectors=True,
            legend=False,
            title='HOX genes in each sample',
            opref='figures/sample_density.pdf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hox_gene'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import cerberus
import pandas as pd

# %%
tss = [1,1,4,2,1]
ic = [4,1,2,2,1]
tes = [1,2,1,2,1]
df = pd.DataFrame()
df['n_tss'] = tss
df['n_ic'] = ic
df['n_tes'] = tes

# %%
df = cerberus.compute_splicing_ratio(df)

# %%
df
# Out:
#    n_tss  n_ic  n_tes  splicing_ratio
# 0      1     4      1        4.000000
# 1      1     1      2        0.666667
# 2      4     2      1        0.800000
# 3      2     2      2        1.000000
# 4      1     1      1        1.000000

# %%
df['total'] = df.n_tss+df.n_tes+df.splicing_ratio
df['tss_ratio'] = df.n_tss/df.total
df['top_ratio'] = df.splicing_ratio/df.total
df['tes_ratio'] = df.n_tes/df.total

# %%
df
# Out:
#    n_tss  n_ic  n_tes  splicing_ratio     total  tss_ratio  top_ratio  \
# 0      1     4      1        4.000000  6.000000   0.166667   0.666667
# 1      1     1      2        0.666667  3.666667   0.272727   0.181818
# 2      4     2      1        0.800000  5.800000   0.689655   0.137931
# 3      2     2      2        1.000000  5.000000   0.400000   0.200000
# 4      1     1      1        1.000000  3.000000   0.333333   0.333333
#
#    tes_ratio
# 0   0.166667
# 1   0.545455
# 2   0.172414
# 3   0.400000
# 4   0.333333

# %%
# gene triplets
df[['n_tss', 'n_ic', 'n_tes']]
# Out:
#    n_tss  n_ic  n_tes
# 0      1     4      1
# 1      1     1      2
# 2      4     2      1
# 3      2     2      2
# 4      1     1      1

# %%
# gene triplets w/ splicing ratio
df[['n_tss', 'splicing_ratio', 'n_tes']]
# Out:
#    n_tss  splicing_ratio  n_tes
# 0      1        4.000000      1
# 1      1        0.666667      2
# 2      4        0.800000      1
# 3      2        1.000000      2
# 4      1        1.000000      1

# %%
# simplex coords
df[['tss_ratio', 'top_ratio', 'tes_ratio']]
# Out:
#    tss_ratio  top_ratio  tes_ratio
# 0   0.166667   0.666667   0.166667
# 1   0.272727   0.181818   0.545455
# 2   0.689655   0.137931   0.172414
# 3   0.400000   0.200000   0.400000
# 4   0.333333   0.333333   0.333333
