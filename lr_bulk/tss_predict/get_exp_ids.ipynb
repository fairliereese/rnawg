# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import matplotlib as mpl
import os
import gseapy as gp
import pdb
import copy
from scipy import sparse
import anndata
import cerberus
import subprocess

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
exp_meta = '../metadata.tsv'
filt_ab = '../cerberus/cerberus_filtered_abundance.tsv'
c_annot = '../cerberus/cerberus_annot.h5'

# %% [markdown]
# ## experiment IDs
#
# Find them and scp them over

# %%
df = pd.read_csv(exp_meta, sep='\t')

# %%
df = df[['Experiment accession', 'Biosample term name']]
samples = ['GM12878', 'K562']
df = df.loc[df['Biosample term name'].isin(samples)]
exp_ids = df['Experiment accession'].unique().tolist()
for e in exp_ids:
    cmd = 'scp freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/{}.bed .'.format(e)
    cmd = cmd.split()
    print(cmd)
    subprocess.run(cmd, check=True)
# Out:
# ['scp', 'freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/ENCSR526TQU.bed', '.']
# ['scp', 'freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/ENCSR962BVU.bed', '.']
# ['scp', 'freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/ENCSR983KDL.bed', '.']
# ['scp', 'freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/ENCSR706ANY.bed', '.']
# ['scp', 'freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/ENCSR589FUJ.bed', '.']
# ['scp', 'freese@hpc3.rcic.uci.edu:/dfs7/samlab/mcelik/rnawg/data/results/lapa/tss/dataset/ENCSR838WFC.bed', '.']

# %% [markdown]
# ## get bed files w/ tpm for each expressed cerberus TSS in gm and k5

# %%
feat = 'tss'
df = pd.read_csv(filt_ab, sep='\t')
df, ic_ids = get_tpm_table(df,
               how=feat,
               min_tpm=1)
# Out:
# Calculating tss TPM values
# /Users/fairliereese/Documents/programming/mortazavi_lab/data/rnawg/scripts/utils.py:1805: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tpm_col] = (df[d]*1000000)/df[total_col]
# /Users/fairliereese/Documents/programming/mortazavi_lab/data/rnawg/scripts/utils.py:1804: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[total_col] = df[d].sum()
# Enforcing minimum TPM
# Total # tsss detected: 76487
# # tsss >= 1 tpm: 67730
# Number of tsss reported: 67730

# %%
# limit only to samples we care about
samples = ['gm12878', 'k562']
cols = []
for s in samples:
    cols += [col for col in df.columns if s in col]

df = df[cols]

# %%
# melt, threshold on min tpm 
df = df.melt(var_name='dataset', value_name='tpm', ignore_index=False)
df = df.loc[df.tpm >= 1]

# %%
# merge w/ cerberus tss info
ca = cerberus.read(c_annot)

# %%
ca.tss.head()
# Out:
#   Chromosome      Start        End Strand               Name  \
# 0       chr1  169794989  169795129      +  ENSG00000000460_1
# 1       chr1  169795358  169795459      +  ENSG00000000460_2
# 2       chr1  169794679  169794780      +  ENSG00000000460_3
# 3       chr1  169795870  169795971      +  ENSG00000000460_4
# 4       chr1  169661956  169662057      +  ENSG00000000460_5
#
#                                               source novelty          gene_id  \
# 0  v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...   Known  ENSG00000000460
# 1                                   v40,v29,lapa,pls   Known  ENSG00000000460
# 2                              v40,v29,lapa,gtex,pls   Known  ENSG00000000460
# 3                                        v40,v29,pls   Known  ENSG00000000460
# 4                                       v40,v29,dels   Known  ENSG00000000460
#
#    tss
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
tss_df = ca.tss.copy(deep=True)
df = df.merge(tss_df, how='left', left_index=True, right_on='Name')

# %%
df['gene_id'] = df.Name.str.split('_', expand=True)[0]
df.head()
# Out:
#             dataset        tpm Chromosome      Start        End Strand  \
# 140910  gm12878_3_1  31.562599      chr20   50958366   50958605      -
# 140917  gm12878_3_1  15.237117      chr20   50936125   50936226      -
# 7180    gm12878_3_1   9.795289       chr1  169893845  169894009      -
# 0       gm12878_3_1  20.678944       chr1  169794989  169795129      +
# 2       gm12878_3_1   4.353462       chr1  169794679  169794780      +
#
#                      Name                                             source  \
# 140910  ENSG00000000419_1  v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...
# 140917  ENSG00000000419_8                                   lapa,encode_cage
# 7180    ENSG00000000457_1  v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...
# 0       ENSG00000000460_1  v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...
# 2       ENSG00000000460_3                              v40,v29,lapa,gtex,pls
#
#        novelty          gene_id  tss
# 140910   Known  ENSG00000000419    1
# 140917   Novel  ENSG00000000419    8
# 7180     Known  ENSG00000000457    1
# 0        Known  ENSG00000000460    1
# 2        Known  ENSG00000000460    3

# %%
cols = ['Chromosome', 'Start', 'End', 'Name', 'Strand', 'gene_id', 'tpm', 'source', 'novelty', 'dataset']
df = df[cols]

# %%
df
# Out:
#        Chromosome      Start        End               Name Strand  \
# 140910      chr20   50958366   50958605  ENSG00000000419_1      -
# 140917      chr20   50936125   50936226  ENSG00000000419_8      -
# 7180         chr1  169893845  169894009  ENSG00000000457_1      -
# 0            chr1  169794989  169795129  ENSG00000000460_1      +
# 2            chr1  169794679  169794780  ENSG00000000460_3      +
# ...           ...        ...        ...                ...    ...
# 123103      chr17   27089494   27089595  ENSG00000285822_1      +
# 108893      chr15   41332804   41332933  ENSG00000285920_3      +
# 47613        chr5   36876606   36876750  ENSG00000285967_2      -
# 51243        chr6   63572421   63572599  ENSG00000285976_1      +
# 51244        chr6   63571961   63572062  ENSG00000285976_2      +
#
#                 gene_id        tpm  \
# 140910  ENSG00000000419  31.562599
# 140917  ENSG00000000419  15.237117
# 7180    ENSG00000000457   9.795289
# 0       ENSG00000000460  20.678944
# 2       ENSG00000000460   4.353462
# ...                 ...        ...
# 123103  ENSG00000285822   2.288277
# 108893  ENSG00000285920  16.017940
# 47613   ENSG00000285967  11.441386
# 51243   ENSG00000285976  75.513146
# 51244   ENSG00000285976  59.495206
#
#                                                    source novelty      dataset
# 140910  v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...   Known  gm12878_3_1
# 140917                                   lapa,encode_cage   Novel  gm12878_3_1
# 7180    v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...   Known  gm12878_3_1
# 0       v40,v29,lapa,gtex,encode_cage,fantom_cage,enco...   Known  gm12878_3_1
# 2                                   v40,v29,lapa,gtex,pls   Known  gm12878_3_1
# ...                                                   ...     ...          ...
# 123103        v40,v29,lapa,fantom_cage,encode_rampage,pls   Known     k562_2_2
# 108893    lapa,encode_cage,fantom_cage,encode_rampage,pls   Novel     k562_2_2
# 47613   v40,v29,lapa,encode_cage,fantom_cage,encode_ra...   Known     k562_2_2
# 51243   v40,lapa,encode_cage,fantom_cage,encode_rampag...   Known     k562_2_2
# 51244                       v29,lapa,fantom_cage,pls,pels   Known     k562_2_2
#
# [168459 rows x 10 columns]

# %%
for d in df.dataset.unique().tolist():
    temp = df.loc[df.dataset==d]
    fname = '{}_cerberus.bed'.format(d)
    temp.to_csv(fname, sep='\t', index=False)
