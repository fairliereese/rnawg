# %%
import pandas as pd
import pyranges as pr

# %%
def get_ic(gtf_pr):
    """
    Get a hyphen-separated representation of each transcript's intron chain
    from a PyRanges GTF

    Parameters:
        gtf_pr (pyranges PyRanges): GTF PyRanges object

    Returns:
        df (pandas DataFrame): DataFrame detailing intron chain, gene, strand,
            chromosome, and transcript that intron chain was seen in
    """
    df = gtf_pr.df.copy(deep=True)

    # restrict to exon entries
    df = df.loc[df.Feature == 'exon']
    cols = ['Chromosome', 'Strand', 'Start', 'End', 'transcript_id', 'gene_id']
    df = df[cols]

    # melt to isolate individual coordinates
    df = pd.melt(df, id_vars=['Chromosome', 'Strand', 'transcript_id', 'gene_id'],
                value_vars=['Start', 'End'],
                value_name='Coord')
    df.drop('variable', axis=1, inplace=True)

    # sort to order coordinates correctly
    df.Coord = df.Coord.astype(int)
    fwd = df.loc[df.Strand == '+'].copy(deep=True)
    rev = df.loc[df.Strand == '-'].copy(deep=True)

    fwd.sort_values(by=['Chromosome', 'transcript_id', 'Coord'],
                    ascending=[True, True, True], inplace=True)
    rev.sort_values(by=['Chromosome', 'transcript_id', 'Coord'],
                    ascending=[True, True, False], inplace=True)
    df = pd.concat([fwd, rev])

    # create intron chain strings
    df.Coord = df.Coord.astype(str)
    df = df.groupby(['Chromosome', 'Strand',
                     'transcript_id', 'gene_id'], observed=True)['Coord'].apply('-'.join).reset_index()

    # remove tss and tes from intron chain
    df['temp'] = df.Coord.str.split('-', n=1, expand=True)[1]
    df['ic'] = df.temp.str.rsplit('-', n=1, expand=True)[0]

    return df

# %% [markdown]
# ## How many filtered novel transcripts' intron chains are supported in v39?

# %%
# TALON transcripts
fname = '/Users/fairliereese/mortazavi_lab/data/rnawg/lr_bulk/talon/human_known_nic_nnc_talon.gtf'
talon = pr.read_gtf(fname, duplicate_attr=True)

nov_df = get_ic(talon)

# limit to just NIC and NNC transcripts
talon = talon.df
nov_tids = talon.loc[(talon.NNC_transcript=='TRUE')|(talon.NNC_transcript=='TRUE')].transcript_id.tolist()
nov_df = nov_df.loc[nov_df.transcript_id.isin(nov_tids)]

# %%
# GENCODE transcripts 
fname = '/Users/fairliereese/mortazavi_lab/ref/gencode.v39/gencode.v39.annotation.gtf'
genc = pr.read_gtf(fname)
genc_df = get_ic(genc)

# %%
nov_df.head()
# Out:
#   Chromosome Strand      transcript_id            gene_id  \
# 0      SIRV1      +  ENCODEHT000206942  ENCODEHG000058846
# 1      SIRV1      -  ENCODEHT000206867  ENCODEHG000058837
# 2      SIRV1      -  ENCODEHT000206868  ENCODEHG000058837
# 3      SIRV1      -  ENCODEHT000206870  ENCODEHG000058837
# 5      SIRV3      +  ENCODEHT000206896  ENCODEHG000058844
#
#                                                Coord  \
# 0                10647-10791-10882-11057-11434-11606
# 1  10790-10647-10366-10282-7814-7552-6813-6560-64...
# 2  10790-10444-10366-10282-7814-7552-6813-6560-64...
# 3                     10790-10553-7808-7552-1484-999
# 5  1980-2005-4568-4779-6057-7988-8127-8207-8755-8937
#
#                                                 temp  \
# 0                      10791-10882-11057-11434-11606
# 1  10647-10366-10282-7814-7552-6813-6560-6473-633...
# 2  10444-10366-10282-7814-7552-6813-6560-6473-633...
# 3                           10553-7808-7552-1484-999
# 5       2005-4568-4779-6057-7988-8127-8207-8755-8937
#
#                                                   ic
# 0                            10791-10882-11057-11434
# 1  10647-10366-10282-7814-7552-6813-6560-6473-633...
# 2  10444-10366-10282-7814-7552-6813-6560-6473-633...
# 3                               10553-7808-7552-1484
# 5            2005-4568-4779-6057-7988-8127-8207-8755

# %%
genc_df.head()
# Out:
#   Chromosome Strand       transcript_id             gene_id  \
# 0       chr1      +   ENST00000003912.7  ENSG00000001461.17
# 1       chr1      +   ENST00000008440.9  ENSG00000010072.16
# 2       chr1      +   ENST00000009105.5  ENSG00000008118.10
# 3       chr1      +  ENST00000010299.10  ENSG00000009780.16
# 4       chr1      +  ENST00000011700.10  ENSG00000048707.15
#
#                                                Coord  \
# 0  24415802-24415904-24419290-24419640-24433103-2...
# 1  231338255-231338604-231339768-231339868-231351...
# 2  209583716-209583932-209594954-209595075-209599...
# 3  27726056-27726161-27727471-27727536-27730231-2...
# 4  12277120-12278038-12279498-12279650-12282704-1...
#
#                                                 temp  \
# 0  24415904-24419290-24419640-24433103-24433213-2...
# 1  231338604-231339768-231339868-231351303-231352521
# 2  209583932-209594954-209595075-209599982-209600...
# 3  27726161-27727471-27727536-27730231-27730333-2...
# 4  12278038-12279498-12279650-12282704-12283736-1...
#
#                                                   ic
# 0  24415904-24419290-24419640-24433103-24433213-2...
# 1            231338604-231339768-231339868-231351303
# 2  209583932-209594954-209595075-209599982-209600...
# 3  27726161-27727471-27727536-27730231-27730333-2...
# 4  12278038-12279498-12279650-12282704-12283736-1...

# %%
# which intron chains from the novel data exist in the new gencode annotation?
nov_df.drop(['temp', 'Coord'], axis=1, inplace=True)
genc_df.drop(['temp', 'Coord'], axis=1, inplace=True)

nov_df = nov_df.merge(genc_df, how='left', on=['Chromosome', 'Strand', 'ic'], suffixes=('_talon', '_genc'))

# %%
nov_df.head()
# Out:
#   Chromosome Strand transcript_id_talon      gene_id_talon  \
# 0      SIRV1      +   ENCODEHT000206942  ENCODEHG000058846
# 1      SIRV1      -   ENCODEHT000206867  ENCODEHG000058837
# 2      SIRV1      -   ENCODEHT000206868  ENCODEHG000058837
# 3      SIRV1      -   ENCODEHT000206870  ENCODEHG000058837
# 4      SIRV3      +   ENCODEHT000206896  ENCODEHG000058844
#
#                                                   ic transcript_id_genc  \
# 0                            10791-10882-11057-11434                NaN
# 1  10647-10366-10282-7814-7552-6813-6560-6473-633...                NaN
# 2  10444-10366-10282-7814-7552-6813-6560-6473-633...                NaN
# 3                               10553-7808-7552-1484                NaN
# 4            2005-4568-4779-6057-7988-8127-8207-8755                NaN
#
#   gene_id_genc
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
temp = nov_df.loc[~nov_df.transcript_id_genc.isnull()]
n = len(temp.index)
supp_tids = temp.transcript_id_genc.str.split('.', n=1, expand=True)[0].tolist()
print('Found {} novel transcripts w/ their intron chains supported by v39'.format(n))
# Out:
# Found 389 novel transcripts w/ their intron chains supported by v39

# %%
n = len(nov_df.loc[~(nov_df.Chromosome.str.contains('SIRV'))&~(nov_df.Chromosome.str.contains('ERCC'))].index)
print('{} novel transcripts (w/o sirv / ercc) total'.format(n))
# Out:
# 8285 novel transcripts (w/o sirv / ercc) total

# %%
temp[['transcript_id_talon', 'transcript_id_genc']].head()
# Out:
#     transcript_id_talon transcript_id_genc
# 23    ENCODEHT000222627  ENST00000394517.7
# 25    ENCODEHT000238573  ENST00000685968.1
# 51    ENCODEHT000494112  ENST00000690421.1
# 100   ENCODEHT000670446  ENST00000677378.1
# 101   ENCODEHT000670479  ENST00000678689.1

# %% [markdown]
# ## How many of these stable transcript ids exist in v29 and in v39?

# %%
# were these transcripts designated at novel because these transcripts just didn't exist in prior versions of the annotation?
fname = '/Users/fairliereese/mortazavi_lab/data/rnawg/refs/gencode_v29_sirv4_ercc.gtf'
v29 = pr.read_gtf(fname)

# %%
fname = '/Users/fairliereese/mortazavi_lab/ref/gencode.v39/gencode.v39.annotation.gtf'
v39 = pr.read_gtf(fname)

# %%
supp_tids[:5]
# Out:
# ['ENST00000394517',
#  'ENST00000685968',
#  'ENST00000690421',
#  'ENST00000677378',
#  'ENST00000678689']

# %%
v29 = v29.df
v29['tid_stable'] = v29.transcript_id.str.split('.', n=1, expand=True)[0]

temp = v29.loc[v29.tid_stable.isin(supp_tids)]
temp = temp.loc[temp.Feature == 'transcript']
n = len(temp.index)
print('{} transcripts whose intron chains are supported in v39 also are annotated in v29'.format(n))
# Out:
# 59 transcripts whose intron chains are supported in v39 also are annotated in v29

# %%
v29.head()
# Out:
#    Chromosome Source Feature  Start   End Score Strand Frame      gene_id  \
# 0  ERCC-00002   ERCC    exon      0  1045     0      +     .  ERCC-00002A
# 1  ERCC-00003   ERCC    exon      0  1007     0      +     .  ERCC-00003A
# 2  ERCC-00004   ERCC    exon      0   507     0      +     .  ERCC-00004A
# 3  ERCC-00009   ERCC    exon      0   968     0      +     .  ERCC-00009A
# 4  ERCC-00012   ERCC    exon      0   978     0      +     .  ERCC-00012A
#
#   gene_type  ...  tag havana_transcript exon_number exon_id  ont protein_id  \
# 0       NaN  ...  NaN               NaN         NaN     NaN  NaN        NaN
# 1       NaN  ...  NaN               NaN         NaN     NaN  NaN        NaN
# 2       NaN  ...  NaN               NaN         NaN     NaN  NaN        NaN
# 3       NaN  ...  NaN               NaN         NaN     NaN  NaN        NaN
# 4       NaN  ...  NaN               NaN         NaN     NaN  NaN        NaN
#
#   ccdsid   gene_biotype exon_assignment tid_stable
# 0    NaN  ERCC_spike_in             NaN   DQ459430
# 1    NaN  ERCC_spike_in             NaN   DQ516784
# 2    NaN  ERCC_spike_in             NaN   DQ516752
# 3    NaN  ERCC_spike_in             NaN   DQ668364
# 4    NaN  ERCC_spike_in             NaN   DQ883670
#
# [5 rows x 27 columns]

# %%
v29.Feature.unique()
# Out:
# array(['exon', 'gene', 'transcript', 'CDS', 'start_codon', 'stop_codon',
#        'UTR', 'Selenocysteine'], dtype=object)

# %%
v29.loc[v29.Feature == 'Selenocysteine']
# Out:
#         Chromosome  Source         Feature     Start       End Score Strand  \
# 20380         chr1  HAVANA  Selenocysteine  25802092  25802095     .      +
# 20381         chr1  HAVANA  Selenocysteine  25812788  25812791     .      +
# 20413         chr1  HAVANA  Selenocysteine  25812788  25812791     .      +
# 46423         chr1  HAVANA  Selenocysteine  53904703  53904706     .      +
# 46435         chr1  HAVANA  Selenocysteine  53904703  53904706     .      +
# ...            ...     ...             ...       ...       ...   ...    ...
# 2620238      chr22  HAVANA  Selenocysteine  19877110  19877113     .      -
# 2620286      chr22  HAVANA  Selenocysteine  19877110  19877113     .      -
# 2620306      chr22  HAVANA  Selenocysteine  19877110  19877113     .      -
# 2629658      chr22  HAVANA  Selenocysteine  31105950  31105953     .      -
# 2629683      chr22  HAVANA  Selenocysteine  31105950  31105953     .      -
#
#         Frame             gene_id       gene_type  ...     tag  \
# 20380       .  ENSG00000162430.16  protein_coding  ...  seleno
# 20381       .  ENSG00000162430.16  protein_coding  ...  seleno
# 20413       .  ENSG00000162430.16  protein_coding  ...  seleno
# 46423       .  ENSG00000211452.10  protein_coding  ...  seleno
# 46435       .  ENSG00000211452.10  protein_coding  ...  seleno
# ...       ...                 ...             ...  ...     ...
# 2620238     .  ENSG00000184470.20  protein_coding  ...  seleno
# 2620286     .  ENSG00000184470.20  protein_coding  ...  seleno
# 2620306     .  ENSG00000184470.20  protein_coding  ...  seleno
# 2629658     .  ENSG00000198832.10  protein_coding  ...  seleno
# 2629683     .  ENSG00000198832.10  protein_coding  ...  seleno
#
#             havana_transcript exon_number exon_id  ont         protein_id  \
# 20380    OTTHUMT00000019314.2         NaN     NaN  NaN  ENSP00000355141.2
# 20381    OTTHUMT00000019314.2         NaN     NaN  NaN  ENSP00000355141.2
# 20413    OTTHUMT00000019315.2         NaN     NaN  NaN  ENSP00000363434.1
# 46423    OTTHUMT00000388166.2         NaN     NaN  NaN  ENSP00000432797.1
# 46435    OTTHUMT00000023247.3         NaN     NaN  NaN  ENSP00000354643.3
# ...                       ...         ...     ...  ...                ...
# 2620238  OTTHUMT00000314903.4         NaN     NaN  NaN  ENSP00000383365.1
# 2620286  OTTHUMT00000314927.3         NaN     NaN  NaN  ENSP00000485499.2
# 2620306  OTTHUMT00000314928.3         NaN     NaN  NaN  ENSP00000485466.2
# 2629658  OTTHUMT00000321789.1         NaN     NaN  NaN  ENSP00000384564.1
# 2629683  OTTHUMT00000321788.1         NaN     NaN  NaN  ENSP00000383155.2
#
#               ccdsid gene_biotype exon_assignment       tid_stable
# 20380    CCDS41282.1          NaN             NaN  ENST00000361547
# 20381    CCDS41282.1          NaN             NaN  ENST00000361547
# 20413    CCDS41283.1          NaN             NaN  ENST00000374315
# 46423            NaN          NaN             NaN  ENST00000529589
# 46435    CCDS41339.1          NaN             NaN  ENST00000361921
# ...              ...          ...             ...              ...
# 2620238  CCDS42981.1          NaN             NaN  ENST00000400521
# 2620286          NaN          NaN             NaN  ENST00000485358
# 2620306          NaN          NaN             NaN  ENST00000462843
# 2629658  CCDS43003.1          NaN             NaN  ENST00000402395
# 2629683  CCDS43003.1          NaN             NaN  ENST00000400299
#
# [120 rows x 27 columns]

# %% [markdown]
# ## How many more reads would be known if we were using v39?

# %%
import sqlite3
import pandas as pd
import pyranges as pr

# %%
db = '../human.db'
annot = '../human_talon_read_annot.tsv'
genome_build = 'hg38'

# %%
def get_ic_from_talon_db(db, annot, genome_build):
    conn = sqlite3.connect(db)

    # get edge annotations
    query = """
            SELECT 
                e.edge_ID,
                loc1.chromosome,
                MIN(loc1.position,loc2.position),
                MAX(loc1.position,loc2.position),
                e.strand
             FROM edge e
             LEFT JOIN location loc1 ON e.v1 = loc1.location_ID
             LEFT JOIN location loc2 ON e.v2 = loc2.location_ID
             WHERE loc1.genome_build = '""" + genome_build + """' AND
             loc2.genome_build = '""" + genome_build + \
             """' AND e.edge_type = 'exon';"""

    e_df = pd.read_sql_query(query, conn)
    e_df.columns = ['eid', 'Chromosome', 'Start', 'End', 'Strand']
    e_df.eid = e_df.eid.astype(int)

    # get transcript annotations 
    query = """
            SELECT 
                   start_exon,
                   end_exon,
                   jn_path,
                   transcript_ID,
                   gene_ID
            FROM transcripts
            """
    t_df = pd.read_sql_query(query, conn)
    t_df['temp'] = t_df.jn_path.str.split(',')
    t_df.drop('jn_path', axis=1, inplace=True)
    t_df = t_df.explode(column='temp')
    t_df = t_df.melt(id_vars=['transcript_ID', 'gene_ID'],
              value_vars=['temp', 'start_exon', 'end_exon'])
    t_df.drop('variable', axis=1, inplace=True)
    t_df.rename({'value': 'temp'}, axis=1, inplace=True)
    t_df.drop_duplicates(inplace=True)
    t_df.rename({'transcript_ID': 'transcript_id',
                 'gene_ID': 'gene_id'},
                axis=1, inplace=True)

    # drop things w/o intron chains (ie monoexonic transcripts)
    t_df = t_df.loc[~t_df.temp.isnull()]

    t_df.temp = t_df.temp.astype(int)

    # add information about each coordinate
    t_df = t_df.merge(e_df, how='left', left_on='temp', right_on='eid')

    # drop all introns
    t_df = t_df.loc[~t_df.eid.isnull()]

    # format as pyranges
    t_df.drop(['temp', 'eid'], axis=1, inplace=True)
    t_df['Feature'] = 'exon'
    t_df.Start = t_df.Start - 1
    t_df = pr.PyRanges(t_df)

    df = get_ic(t_df)
    
    # get novelty type of each transcript
    query = """
            SELECT 
                ID,
                value
            FROM transcript_annotations
            WHERE transcript_annotations.attribute = 'transcript_status'
                AND transcript_annotations.value = 'KNOWN'
            """
    known_df = pd.read_sql_query(query, conn)
    
    known_df.rename({'ID': 'transcript_id'}, axis=1, inplace=True)
    known_df.drop('value', axis=1, inplace=True)
    known_df['v29'] = True
    
    df = df.merge(known_df, how='left', on='transcript_id')    
    
    # everything that wasn't known gets "false"
    df.v29.fillna(value=False, inplace=True)

    return df

# %%
df = get_ic_from_talon_db(db, annot, genome_build)

# %%
df.to_csv('human_talon_ics.tsv', sep='\t', index=False)

# %%
df = pd.read_csv('human_talon_ics.tsv', sep='\t')

# %%
# restrict to only known transcripts
df = df.loc[df.v29 == False]

# %%
df.loc[df.transcript_id == 222627, 'ic'].tolist()
# Out:
# ['1059782-1060276-1060393-1061019-1061117-1063078-1063201-1065829']

# %%
# get intron chains from v39 transcripts
fname = '/Users/fairliereese/mortazavi_lab/ref/gencode.v39/gencode.v39.annotation.gtf'
genc = pr.read_gtf(fname)
genc_df = get_ic(genc)

# %%
genc_df.head()
genc_df.to_csv('gencode_v39_ics.tsv', sep='\t', index=False)

# %%
df = df.merge(genc_df, how='left', on=['Chromosome', 'Strand', 'ic'], suffixes=('_talon', '_genc'))

# %%
print('from talon gtf')
print(temp.loc[temp.transcript_id_talon == 'ENCODEHT000222627', ['Chromosome', 'Strand']])
temp.loc[temp.transcript_id_talon == 'ENCODEHT000222627', 'ic'].tolist()

# %%
print('from gencode v39')
print(genc_df.loc[genc_df.transcript_id == 'ENST00000394517.7', ['Chromosome', 'Strand']])
genc_df.loc[genc_df.transcript_id == 'ENST00000394517.7', 'ic'].tolist()
# Out:
# from gencode v39
#      Chromosome Strand
# 2141       chr1      +
# ['1059782-1060276-1060393-1061019-1061117-1063078-1063201-1065829']

# %%
print('from talon db')
print(df.loc[df.transcript_id_talon == 222627, ['Chromosome', 'Strand']])
df.loc[df.transcript_id_talon == 222627, 'ic'].tolist()
# Out:
# from talon db
#      Chromosome Strand
# 1287       chr1      +
# ['1059782-1060276-1060393-1061019-1061117-1063078-1063201-1065829']

# %%
df.head()
# Out:
#    Chromosome Strand  transcript_id_talon  gene_id_talon     Coord_talon  \
# 0  ERCC-00002      +               206802          58798          0-1035
# 1  ERCC-00002      +               206838          58798   0-61-141-1035
# 2  ERCC-00002      +               206839          58798  0-344-399-1035
# 3  ERCC-00002      +              1149583          58798  0-887-942-1035
# 4  ERCC-00002      +              1149585          58798  0-195-510-1035
#
#      temp_talon       ic    v29 transcript_id_genc gene_id_genc Coord_genc  \
# 0          1035     1035  False                NaN          NaN        NaN
# 1   61-141-1035   61-141  False                NaN          NaN        NaN
# 2  344-399-1035  344-399  False                NaN          NaN        NaN
# 3  887-942-1035  887-942  False                NaN          NaN        NaN
# 4  195-510-1035  195-510  False                NaN          NaN        NaN
#
#   temp_genc
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.loc[df.transcript_id_talon == 222627]
# Out:
#      Chromosome Strand  transcript_id_talon  gene_id_talon  \
# 1287       chr1      +               222627             72
#
#                                             Coord_talon  \
# 1287  1059733-1059782-1060276-1060393-1061019-106111...
#
#                                              temp_talon  \
# 1287  1059782-1060276-1060393-1061019-1061117-106307...
#
#                                                      ic    v29  \
# 1287  1059782-1060276-1060393-1061019-1061117-106307...  False
#
#      transcript_id_genc        gene_id_genc  \
# 1287  ENST00000394517.7  ENSG00000217801.11
#
#                                              Coord_genc  \
# 1287  1059707-1059782-1060276-1060393-1061019-106111...
#
#                                               temp_genc
# 1287  1059782-1060276-1060393-1061019-1061117-106307...

# %%
df['v39'] = False
df.loc[~df.transcript_id_genc.isnull(), 'v39'] = True

# %%
df.loc[df.v39 == True]
v39_tids = df.loc[df.v39 == True, 'transcript_id_talon'].tolist()

# %%
# how many reads do these transcripts correspond to in the read_annot file?
read_df = pd.read_csv('../human_talon_read_annot.tsv', sep='\t', usecols=[10])

# %%
total_reads = len(read_df.index)
print(total_reads)
# Out:
# 181558331

# %%
nov_v39_reads = len(read_df.loc[read_df.transcript_ID.isin(v39_tids)].index)

# %%
known_reads = len(read_df.index)-nov_v39_reads

# %%
print(nov_v39_reads)
# Out:
# 2058984

# %%
print(known_reads)
# Out:
# 179499347

# %%
print((nov_v39_reads/total_reads)*100)
# Out:
# 1.134061978130874

# %%
len(v39_tids)
# Out:
# 16324

# %%
v39_tids[:5]
# Out:
# [208393, 208410, 208584, 208597, 208599]

# %%
# and then how many of these table transcript IDs are in v29 but these reads were
# not assigned to those models (presumably because of differences at the ends)
temp = df.loc[~df.transcript_id_genc.isnull()]
supp_tids = temp.transcript_id_genc.str.split('.', n=1, expand=True)[0].tolist()

# %%
len(supp_tids)
# Out:
# 16324

# %%
# were these transcripts designated at novel because these transcripts just didn't exist in prior versions of the annotation?
fname = '/Users/fairliereese/mortazavi_lab/data/rnawg/refs/gencode_v29_sirv4_ercc.gtf'
v29 = pr.read_gtf(fname)

# %%
fname = '/Users/fairliereese/mortazavi_lab/ref/gencode.v39/gencode.v39.annotation.gtf'
v39 = pr.read_gtf(fname)

# %%
v29 = v29.df
v29['tid_stable'] = v29.transcript_id.str.split('.', n=1, expand=True)[0]

temp = v29.loc[v29.tid_stable.isin(supp_tids)]
temp = temp.loc[temp.Feature == 'transcript']
n = len(temp.index)
print('{} transcripts whose intron chains are supported in v39 also are annotated in v29'.format(n))
# Out:
# 2318 transcripts whose intron chains are supported in v39 also are annotated in v29

# %% [markdown]
# ## Does pyranges lengthen intervals when it reads GTFs in?
# Yes [gh issue](https://github.com/biocore-ntnu/pyranges/pull/260)

# %%
beep = pr.read_gtf('confusing_transcript_talon.gtf')

# %%
beep
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +22   |
# | (category)   | (object)   | (category)   |   (int32) |   (int32) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr1         | HAVANA     | gene         |   1059733 |   1066441 | ...   |
# | chr1         | TALON      | transcript   |   1059733 |   1066441 | ...   |
# | chr1         | TALON      | exon         |   1059733 |   1059782 | ...   |
# | chr1         | TALON      | exon         |   1060276 |   1060393 | ...   |
# | chr1         | HAVANA     | exon         |   1061019 |   1061117 | ...   |
# | chr1         | HAVANA     | exon         |   1063078 |   1063201 | ...   |
# | chr1         | TALON      | exon         |   1065829 |   1066441 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 7 rows and 27 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 22 hidden columns: Score, Strand, Frame, gene_id, gene_name, gene_status, gene_type, ... (+ 15 more.)
