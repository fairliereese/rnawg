# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import gseapy as gp

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
df = pd.read_csv('human_talon_abundance.tsv', sep='\t')
df, inds = get_tpm_table(df,
                   how='iso',
                   min_tpm=1,
                   sample='brain', 
                   gene_subset='polya')
# Out:
# Calculating iso TPM values
# Subsetting for polya genes
# Enforcing minimum TPM
# Total # isos detected: 5401754
# # isos >= 1 tpm: 235794
# Applying gene type and novelty subset
# Number of isos reported: 151058

# %%
gene_df = pd.read_csv('human_talon_abundance.tsv', sep='\t')
gene_df = gene_df[['annot_gene_name', 'annot_transcript_id']]

# %%
gene_df
# Out:
#            annot_gene_name annot_transcript_id
# 0                MIR6859-1   ENST00000619216.1
# 1              MIR1302-2HG   ENST00000469289.1
# 2                  FAM138A   ENST00000417324.1
# 3                  FAM138A   ENST00000461467.1
# 4               AL627309.1   ENST00000453576.2
# ...                    ...                 ...
# 5401749             ZNF692   ENCODEHT005511812
# 5401750  ENCODEHG000173225   ENCODEHT005511813
# 5401751              PGBD2   ENCODEHT005511814
# 5401752  ENCODEHG000614552   ENCODEHT005511815
# 5401753  ENCODEHG000614553   ENCODEHT005511816
#
# [5401754 rows x 2 columns]

# %%
df = df.merge(gene_df, how='left', left_index=True, right_on='annot_transcript_id')

# %%
df.head()
# Out:
#     brodmann_area_46_1_1  brodmann_area_46_7_1  brodmann_area_46_5_1  \
# 8               1.778265              2.903556              7.091299
# 17              0.000000              0.967852              0.393961
# 18              1.778265              0.000000              2.363766
# 19              3.556529              1.451778              2.757727
# 22              3.556529              0.000000              0.393961
#
#     brodmann_area_46_6_1  brodmann_area_46_8_1  brodmann_area_46_4_1  \
# 8               4.497588              7.131835              8.274235
# 17              1.037905              0.445740              0.000000
# 18              0.000000              0.891479              0.752203
# 19              1.383873              1.337219              1.128305
# 22              0.345968              0.000000              0.000000
#
#     brodmann_area_46_2_1  brodmann_area_46_9_1  brodmann_area_46_3_1  \
# 8               5.213049              4.328380              4.989442
# 17              1.158455              1.082095              0.997888
# 18              0.000000              0.360698              0.997888
# 19              0.579228              0.721397              0.997888
# 22              0.579228              1.082095              1.995777
#
#    annot_gene_name annot_transcript_id
# 8       FO538757.1   ENST00000623083.4
# 17        MTND1P23   ENST00000416931.1
# 18        MTND2P28   ENST00000457540.1
# 19        MTCO1P12   ENST00000414273.1
# 22        MTATP6P1   ENST00000514057.1

# %%
df.loc[df.annot_gene_name == 'SCN1A']
# Out:
#          brodmann_area_46_1_1  brodmann_area_46_7_1  brodmann_area_46_5_1  \
# 12980                1.778265              2.419630              1.575844
# 749578               0.000000              0.483926              0.393961
# 749579               1.778265              0.000000              0.000000
# 1582123              1.778265              0.967852              0.787922
# 2145776              0.000000              0.000000              0.000000
# 3061026              5.334794              2.903556              2.757727
# 3061033              0.000000              0.000000              0.000000
# 4066560              1.778265              0.000000              0.000000
# 5349421              0.000000              0.483926              0.787922
# 5349442              1.778265              0.000000              0.000000
# 5349454              1.778265              0.000000              0.000000
# 5349473              0.000000              0.000000              0.393961
# 5349474              1.778265              0.000000              0.000000
# 5349488              1.778265              0.000000              0.000000
#
#          brodmann_area_46_6_1  brodmann_area_46_8_1  brodmann_area_46_4_1  \
# 12980                2.075810              5.348876              1.504406
# 749578               1.037905              1.782959              1.880508
# 749579               0.345968              0.000000              0.376102
# 1582123              1.729842              2.674438              2.256610
# 2145776              0.000000              0.000000              0.000000
# 3061026              1.383873              2.674438              1.504406
# 3061033              0.345968              0.445740              0.000000
# 4066560              0.000000              0.000000              0.000000
# 5349421              1.037905              1.337219              0.752203
# 5349442              0.000000              0.000000              0.000000
# 5349454              0.000000              0.000000              0.000000
# 5349473              1.037905              1.337219              0.376102
# 5349474              0.691937              1.782959              0.376102
# 5349488              0.000000              0.000000              0.000000
#
#          brodmann_area_46_2_1  brodmann_area_46_9_1  brodmann_area_46_3_1  \
# 12980                3.475366              3.246285              0.997888
# 749578               2.316910              1.082095              0.997888
# 749579               0.000000              0.000000              0.000000
# 1582123              1.158455              2.164190              1.995777
# 2145776              0.000000              1.442793              0.000000
# 3061026              4.633821              2.524888              5.987331
# 3061033              0.000000              1.082095              0.000000
# 4066560              0.000000              0.000000              0.000000
# 5349421              0.579228              0.721397              0.997888
# 5349442              0.000000              0.000000              0.000000
# 5349454              0.000000              0.000000              0.000000
# 5349473              0.579228              0.721397              2.993665
# 5349474              0.000000              0.360698              0.000000
# 5349488              0.000000              0.000000              0.000000
#
#         annot_gene_name annot_transcript_id
# 12980             SCN1A   ENST00000507401.2
# 749578            SCN1A   ENCODEHT000859641
# 749579            SCN1A   ENCODEHT000859642
# 1582123           SCN1A   ENCODEHT001692186
# 2145776           SCN1A   ENCODEHT002255839
# 3061026           SCN1A   ENCODEHT003171089
# 3061033           SCN1A   ENCODEHT003171096
# 4066560           SCN1A   ENCODEHT004176623
# 5349421           SCN1A   ENCODEHT005459484
# 5349442           SCN1A   ENCODEHT005459505
# 5349454           SCN1A   ENCODEHT005459517
# 5349473           SCN1A   ENCODEHT005459536
# 5349474           SCN1A   ENCODEHT005459537
# 5349488           SCN1A   ENCODEHT005459551

# %%
t_df = pd.read_csv('human_talon_abundance_filtered.tsv', sep='\t')

# %%
t_df.loc[t_df.annot_gene_name == 'SCN1A']
# Out:
#         gene_ID  transcript_ID       annot_gene_id annot_transcript_id  \
# 12980      8024          27920  ENSG00000144285.19   ENST00000507401.2
# 178364     8024        1692186  ENSG00000144285.19   ENCODEHT001692186
#
#        annot_gene_name annot_transcript_name  n_exons  length gene_novelty  \
# 12980            SCN1A             SCN1A-207        3     711        Known
# 178364           SCN1A     ENCODEHT001692186        1    3263        Known
#
#        transcript_novelty  ... calu3_1_2  brodmann_area_46_1_1  \
# 12980               Known  ...         0                     1
# 178364                ISM  ...         0                     1
#
#         brodmann_area_46_7_1  brodmann_area_46_5_1  brodmann_area_46_6_1  \
# 12980                      5                     4                     6
# 178364                     2                     2                     5
#
#         brodmann_area_46_8_1  brodmann_area_46_4_1  brodmann_area_46_2_1  \
# 12980                     12                     4                     6
# 178364                     6                     6                     2
#
#         brodmann_area_46_9_1  brodmann_area_46_3_1
# 12980                      9                     1
# 178364                     6                     2
#
# [2 rows x 149 columns]

# %%
df = pd.read_csv('human_talon_abundance.tsv', sep='\t')
df = df.loc[df.annot_gene_name == 'SCN1A']

# %%
df.head()
# Out:
#         gene_ID  transcript_ID       annot_gene_id annot_transcript_id  \
# 12980      8024          27920  ENSG00000144285.19   ENST00000507401.2
# 749565     8024         859628  ENSG00000144285.19   ENCODEHT000859628
# 749567     8024         859630  ENSG00000144285.19   ENCODEHT000859630
# 749575     8024         859638  ENSG00000144285.19   ENCODEHT000859638
# 749578     8024         859641  ENSG00000144285.19   ENCODEHT000859641
#
#        annot_gene_name annot_transcript_name  n_exons  length gene_novelty  \
# 12980            SCN1A             SCN1A-207        3     711        Known
# 749565           SCN1A     ENCODEHT000859628       17    3383        Known
# 749567           SCN1A     ENCODEHT000859630        1     793        Known
# 749575           SCN1A     ENCODEHT000859638        1    1175        Known
# 749578           SCN1A     ENCODEHT000859641        3    1194        Known
#
#        transcript_novelty  ... calu3_1_2  brodmann_area_46_1_1  \
# 12980               Known  ...         0                     1
# 749565                NIC  ...         0                     0
# 749567            Genomic  ...         0                     0
# 749575            Genomic  ...         0                     0
# 749578                ISM  ...         0                     0
#
#         brodmann_area_46_7_1  brodmann_area_46_5_1  brodmann_area_46_6_1  \
# 12980                      5                     4                     6
# 749565                     0                     0                     0
# 749567                     0                     0                     0
# 749575                     0                     0                     0
# 749578                     1                     1                     3
#
#         brodmann_area_46_8_1  brodmann_area_46_4_1  brodmann_area_46_2_1  \
# 12980                     12                     4                     6
# 749565                     0                     0                     0
# 749567                     0                     0                     0
# 749575                     0                     0                     0
# 749578                     4                     5                     4
#
#         brodmann_area_46_9_1  brodmann_area_46_3_1
# 12980                      9                     1
# 749565                     0                     0
# 749567                     0                     0
# 749575                     0                     0
# 749578                     3                     1
#
# [5 rows x 149 columns]

# %%
brain_cols = [c for c in df.columns if 'brodmann' in c]

# %%
temp = df[['annot_transcript_name', 'transcript_novelty']+brain_cols]
temp.set_index('annot_transcript_name', inplace=True)
temp = temp.groupby('transcript_novelty').sum()
temp.sum(axis=1)
# Out:
# transcript_novelty
# Genomic     44
# ISM        155
# Known       48
# NIC         24
# NNC          5
# dtype: int64

# %%
44+155+48+24+5
# Out:
# 276

# %%
48/276
# Out:
# 0.17391304347826086

# %%
df.head()
# Out:
#         gene_ID  transcript_ID       annot_gene_id annot_transcript_id  \
# 12980      8024          27920  ENSG00000144285.19   ENST00000507401.2
# 749565     8024         859628  ENSG00000144285.19   ENCODEHT000859628
# 749567     8024         859630  ENSG00000144285.19   ENCODEHT000859630
# 749575     8024         859638  ENSG00000144285.19   ENCODEHT000859638
# 749578     8024         859641  ENSG00000144285.19   ENCODEHT000859641
#
#        annot_gene_name annot_transcript_name  n_exons  length gene_novelty  \
# 12980            SCN1A             SCN1A-207        3     711        Known
# 749565           SCN1A     ENCODEHT000859628       17    3383        Known
# 749567           SCN1A     ENCODEHT000859630        1     793        Known
# 749575           SCN1A     ENCODEHT000859638        1    1175        Known
# 749578           SCN1A     ENCODEHT000859641        3    1194        Known
#
#        transcript_novelty  ... calu3_1_2  brodmann_area_46_1_1  \
# 12980               Known  ...         0                     1
# 749565                NIC  ...         0                     0
# 749567            Genomic  ...         0                     0
# 749575            Genomic  ...         0                     0
# 749578                ISM  ...         0                     0
#
#         brodmann_area_46_7_1  brodmann_area_46_5_1  brodmann_area_46_6_1  \
# 12980                      5                     4                     6
# 749565                     0                     0                     0
# 749567                     0                     0                     0
# 749575                     0                     0                     0
# 749578                     1                     1                     3
#
#         brodmann_area_46_8_1  brodmann_area_46_4_1  brodmann_area_46_2_1  \
# 12980                     12                     4                     6
# 749565                     0                     0                     0
# 749567                     0                     0                     0
# 749575                     0                     0                     0
# 749578                     4                     5                     4
#
#         brodmann_area_46_9_1  brodmann_area_46_3_1
# 12980                      9                     1
# 749565                     0                     0
# 749567                     0                     0
# 749575                     0                     0
# 749578                     3                     1
#
# [5 rows x 149 columns]

# %%
df = df[['gene_ID', 'transcript_ID']]
df.to_csv('/Users/fairliereese/mortazavi_lab/data/rnawg/lr_bulk/check_scn1a/scn1a_pass_list.csv', index=False, header=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5d6dc3dde3d7> in <module>
# ----> 1 df = df[['gene_ID', 'transcript_ID']]
#       2 df.to_csv('/Users/fairliereese/mortazavi_lab/data/rnawg/lr_bulk/check_scn1a/scn1a_pass_list.csv', index=False, header=None)
#
# NameError: name 'df' is not defined

# %%
# import swan_vis as swan

# %%
# annot = '../../refs/gencode_v29_sirv4_ercc.gtf'
# gtf = 'scn1a_talon.gtf'

# # sg = swan.SwanGraph()
# # sg.add_annotation(annot)
# # sg.save_graph('swan')
# sg = swan.read('swan.p')
# sg.add_transcriptome(gtf)

# %%
# tids = sg.t_df.loc[sg.t_df.gname == 'SCN1A', 'tid'].tolist()
# print(len(tids))
# # sg.plot_each_transcript(tids, prefix='figures/scn1a', indicate_novel=True)
