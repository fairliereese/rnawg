# %%
import swan_vis as swan

# %%
annot = '../../refs/gencode_v29_sirv4_ercc.gtf'
gtf = 'scn1a_talon.gtf'

# sg = swan.SwanGraph()
# sg.add_annotation(annot)
# sg.save_graph('swan')
sg = swan.read('swan.p')
sg.add_transcriptome(gtf)
# Out:
# Read in graph from swan.p
#
# Adding transcriptome to the SwanGraph

# %%
tids = sg.t_df.loc[sg.t_df.gname == 'SCN1A', 'tid'].tolist()
print(len(tids))
sg.plot_each_transcript(tids, prefix='figures/scn1a', indicate_novel=True)
# Out:
# 93
# Saving transcript path graph for ENCODEHT000859628 as figures/scn1a_novel_ENCODEHT000859628_path.png
# Saving transcript path graph for ENCODEHT000859630 as figures/scn1a_novel_ENCODEHT000859630_path.png
# Saving transcript path graph for ENCODEHT000859638 as figures/scn1a_novel_ENCODEHT000859638_path.png
# Saving transcript path graph for ENCODEHT000859642 as figures/scn1a_novel_ENCODEHT000859642_path.png
# Saving transcript path graph for ENCODEHT001692190 as figures/scn1a_novel_ENCODEHT001692190_path.png
# Saving transcript path graph for ENCODEHT001692191 as figures/scn1a_novel_ENCODEHT001692191_path.png
# Saving transcript path graph for ENCODEHT001692195 as figures/scn1a_novel_ENCODEHT001692195_path.png
# Saving transcript path graph for ENCODEHT001692198 as figures/scn1a_novel_ENCODEHT001692198_path.png
# Saving transcript path graph for ENCODEHT001692199 as figures/scn1a_novel_ENCODEHT001692199_path.png
# Saving transcript path graph for ENCODEHT001692200 as figures/scn1a_novel_ENCODEHT001692200_path.png
# Saving transcript path graph for ENCODEHT001692203 as figures/scn1a_novel_ENCODEHT001692203_path.png
# Saving transcript path graph for ENCODEHT001692204 as figures/scn1a_novel_ENCODEHT001692204_path.png
# Saving transcript path graph for ENCODEHT001692208 as figures/scn1a_novel_ENCODEHT001692208_path.png
# Saving transcript path graph for ENCODEHT001692211 as figures/scn1a_novel_ENCODEHT001692211_path.png
# Saving transcript path graph for ENCODEHT002255837 as figures/scn1a_novel_ENCODEHT002255837_path.png
# Saving transcript path graph for ENCODEHT002255839 as figures/scn1a_novel_ENCODEHT002255839_path.png
# Saving transcript path graph for ENCODEHT002255840 as figures/scn1a_novel_ENCODEHT002255840_path.png
# Saving transcript path graph for ENCODEHT002255843 as figures/scn1a_novel_ENCODEHT002255843_path.png
# Saving transcript path graph for ENCODEHT002255848 as figures/scn1a_novel_ENCODEHT002255848_path.png
# Saving transcript path graph for ENCODEHT002766616 as figures/scn1a_novel_ENCODEHT002766616_path.png
# Saving transcript path graph for ENCODEHT002766620 as figures/scn1a_novel_ENCODEHT002766620_path.png
# Saving transcript path graph for ENCODEHT003171081 as figures/scn1a_novel_ENCODEHT003171081_path.png
# Saving transcript path graph for ENCODEHT003171082 as figures/scn1a_novel_ENCODEHT003171082_path.png
# Saving transcript path graph for ENCODEHT003171085 as figures/scn1a_novel_ENCODEHT003171085_path.png
# Saving transcript path graph for ENCODEHT003171090 as figures/scn1a_novel_ENCODEHT003171090_path.png
# Saving transcript path graph for ENCODEHT003171095 as figures/scn1a_novel_ENCODEHT003171095_path.png
# Saving transcript path graph for ENCODEHT003171096 as figures/scn1a_novel_ENCODEHT003171096_path.png
# Saving transcript path graph for ENCODEHT003520054 as figures/scn1a_novel_ENCODEHT003520054_path.png
# Saving transcript path graph for ENCODEHT003520055 as figures/scn1a_novel_ENCODEHT003520055_path.png
# Saving transcript path graph for ENCODEHT003520056 as figures/scn1a_novel_ENCODEHT003520056_path.png
# Saving transcript path graph for ENCODEHT003520058 as figures/scn1a_novel_ENCODEHT003520058_path.png
# Saving transcript path graph for ENCODEHT003658240 as figures/scn1a_novel_ENCODEHT003658240_path.png
# Saving transcript path graph for ENCODEHT004176606 as figures/scn1a_novel_ENCODEHT004176606_path.png
# Saving transcript path graph for ENCODEHT004176608 as figures/scn1a_novel_ENCODEHT004176608_path.png
# Saving transcript path graph for ENCODEHT004176609 as figures/scn1a_novel_ENCODEHT004176609_path.png
# Saving transcript path graph for ENCODEHT004176611 as figures/scn1a_novel_ENCODEHT004176611_path.png
# Saving transcript path graph for ENCODEHT004176616 as figures/scn1a_novel_ENCODEHT004176616_path.png
# Saving transcript path graph for ENCODEHT004176621 as figures/scn1a_novel_ENCODEHT004176621_path.png
# Saving transcript path graph for ENCODEHT004176623 as figures/scn1a_novel_ENCODEHT004176623_path.png
# Saving transcript path graph for ENCODEHT004176627 as figures/scn1a_novel_ENCODEHT004176627_path.png
# Saving transcript path graph for ENCODEHT004176628 as figures/scn1a_novel_ENCODEHT004176628_path.png
# Saving transcript path graph for ENCODEHT004769722 as figures/scn1a_novel_ENCODEHT004769722_path.png
# Saving transcript path graph for ENCODEHT004769724 as figures/scn1a_novel_ENCODEHT004769724_path.png
# Saving transcript path graph for ENCODEHT004769725 as figures/scn1a_novel_ENCODEHT004769725_path.png
# Saving transcript path graph for ENCODEHT004769729 as figures/scn1a_novel_ENCODEHT004769729_path.png
# Saving transcript path graph for ENCODEHT004769731 as figures/scn1a_novel_ENCODEHT004769731_path.png
# Saving transcript path graph for ENCODEHT004769733 as figures/scn1a_novel_ENCODEHT004769733_path.png
# Saving transcript path graph for ENCODEHT004769734 as figures/scn1a_novel_ENCODEHT004769734_path.png
# Saving transcript path graph for ENCODEHT005459484 as figures/scn1a_novel_ENCODEHT005459484_path.png
# Saving transcript path graph for ENCODEHT005459494 as figures/scn1a_novel_ENCODEHT005459494_path.png
# Saving transcript path graph for ENCODEHT005459495 as figures/scn1a_novel_ENCODEHT005459495_path.png
# Saving transcript path graph for ENCODEHT005459500 as figures/scn1a_novel_ENCODEHT005459500_path.png
# Saving transcript path graph for ENCODEHT005459502 as figures/scn1a_novel_ENCODEHT005459502_path.png
# Saving transcript path graph for ENCODEHT005459505 as figures/scn1a_novel_ENCODEHT005459505_path.png
# Saving transcript path graph for ENCODEHT005459507 as figures/scn1a_novel_ENCODEHT005459507_path.png
# Saving transcript path graph for ENCODEHT005459510 as figures/scn1a_novel_ENCODEHT005459510_path.png
# Saving transcript path graph for ENCODEHT005459517 as figures/scn1a_novel_ENCODEHT005459517_path.png
# Saving transcript path graph for ENCODEHT005459521 as figures/scn1a_novel_ENCODEHT005459521_path.png
# Saving transcript path graph for ENCODEHT005459522 as figures/scn1a_novel_ENCODEHT005459522_path.png
# Saving transcript path graph for ENCODEHT005459525 as figures/scn1a_novel_ENCODEHT005459525_path.png
# Saving transcript path graph for ENCODEHT005459529 as figures/scn1a_novel_ENCODEHT005459529_path.png
# Saving transcript path graph for ENCODEHT005459534 as figures/scn1a_novel_ENCODEHT005459534_path.png
# Saving transcript path graph for ENCODEHT005459539 as figures/scn1a_novel_ENCODEHT005459539_path.png
# Saving transcript path graph for ENCODEHT005459540 as figures/scn1a_novel_ENCODEHT005459540_path.png
# Saving transcript path graph for ENCODEHT005459543 as figures/scn1a_novel_ENCODEHT005459543_path.png
# Saving transcript path graph for ENCODEHT005459546 as figures/scn1a_novel_ENCODEHT005459546_path.png
# Saving transcript path graph for ENCODEHT005459547 as figures/scn1a_novel_ENCODEHT005459547_path.png
# Saving transcript path graph for ENCODEHT005459549 as figures/scn1a_novel_ENCODEHT005459549_path.png
# Saving transcript path graph for ENCODEHT005459567 as figures/scn1a_novel_ENCODEHT005459567_path.png
# Saving transcript path graph for ENCODEHT005459571 as figures/scn1a_novel_ENCODEHT005459571_path.png
# Saving transcript path graph for ENCODEHT005459587 as figures/scn1a_novel_ENCODEHT005459587_path.png
# Saving transcript path graph for ENST00000303395.8 as figures/scn1a_novel_ENST00000303395.8_path.png
# Saving transcript path graph for ENST00000375405.7 as figures/scn1a_novel_ENST00000375405.7_path.png
# Saving transcript path graph for ENST00000409050.1 as figures/scn1a_novel_ENST00000409050.1_path.png
# Saving transcript path graph for ENST00000423058.6 as figures/scn1a_novel_ENST00000423058.6_path.png
# Saving transcript path graph for ENST00000473295.2 as figures/scn1a_novel_ENST00000473295.2_path.png
# Saving transcript path graph for ENST00000491429.1 as figures/scn1a_novel_ENST00000491429.1_path.png
# Saving transcript path graph for ENST00000507401.2 as figures/scn1a_novel_ENST00000507401.2_path.png
# Saving transcript path graph for ENST00000625916.1 as figures/scn1a_novel_ENST00000625916.1_path.png
# Saving transcript path graph for ENST00000635750.1 as figures/scn1a_novel_ENST00000635750.1_path.png
# Saving transcript path graph for ENST00000635776.1 as figures/scn1a_novel_ENST00000635776.1_path.png
# Saving transcript path graph for ENST00000635893.1 as figures/scn1a_novel_ENST00000635893.1_path.png
# Saving transcript path graph for ENST00000636194.1 as figures/scn1a_novel_ENST00000636194.1_path.png
# Saving transcript path graph for ENST00000636759.1 as figures/scn1a_novel_ENST00000636759.1_path.png
# Saving transcript path graph for ENST00000637038.1 as figures/scn1a_novel_ENST00000637038.1_path.png
# Saving transcript path graph for ENST00000637285.2 as figures/scn1a_novel_ENST00000637285.2_path.png
# Saving transcript path graph for ENST00000637968.1 as figures/scn1a_novel_ENST00000637968.1_path.png
# Saving transcript path graph for ENST00000637988.1 as figures/scn1a_novel_ENST00000637988.1_path.png
# Saving transcript path graph for ENST00000640036.1 as figures/scn1a_novel_ENST00000640036.1_path.png
# Saving transcript path graph for ENST00000641575.1 as figures/scn1a_novel_ENST00000641575.1_path.png
# Saving transcript path graph for ENST00000641603.1 as figures/scn1a_novel_ENST00000641603.1_path.png
# Saving transcript path graph for ENST00000641996.1 as figures/scn1a_novel_ENST00000641996.1_path.png
# Saving transcript path graph for ENST00000642141.1 as figures/scn1a_novel_ENST00000642141.1_path.png

# %%
sg.plot_each_transcript(tids, prefix='figures/scn1a', browser=True)
# Out:
# Saving transcript path graph for ENCODEHT000859628 as figures/scn1a_browser_ENCODEHT000859628_path.png
# Saving transcript path graph for ENCODEHT000859630 as figures/scn1a_browser_ENCODEHT000859630_path.png
# Saving transcript path graph for ENCODEHT000859638 as figures/scn1a_browser_ENCODEHT000859638_path.png
# Saving transcript path graph for ENCODEHT000859642 as figures/scn1a_browser_ENCODEHT000859642_path.png
# Saving transcript path graph for ENCODEHT001692190 as figures/scn1a_browser_ENCODEHT001692190_path.png
# Saving transcript path graph for ENCODEHT001692191 as figures/scn1a_browser_ENCODEHT001692191_path.png
# Saving transcript path graph for ENCODEHT001692195 as figures/scn1a_browser_ENCODEHT001692195_path.png
# Saving transcript path graph for ENCODEHT001692198 as figures/scn1a_browser_ENCODEHT001692198_path.png
# Saving transcript path graph for ENCODEHT001692199 as figures/scn1a_browser_ENCODEHT001692199_path.png
# Saving transcript path graph for ENCODEHT001692200 as figures/scn1a_browser_ENCODEHT001692200_path.png
# Saving transcript path graph for ENCODEHT001692203 as figures/scn1a_browser_ENCODEHT001692203_path.png
# Saving transcript path graph for ENCODEHT001692204 as figures/scn1a_browser_ENCODEHT001692204_path.png
# Saving transcript path graph for ENCODEHT001692208 as figures/scn1a_browser_ENCODEHT001692208_path.png
# Saving transcript path graph for ENCODEHT001692211 as figures/scn1a_browser_ENCODEHT001692211_path.png
# Saving transcript path graph for ENCODEHT002255837 as figures/scn1a_browser_ENCODEHT002255837_path.png
# Saving transcript path graph for ENCODEHT002255839 as figures/scn1a_browser_ENCODEHT002255839_path.png
# Saving transcript path graph for ENCODEHT002255840 as figures/scn1a_browser_ENCODEHT002255840_path.png
# Saving transcript path graph for ENCODEHT002255843 as figures/scn1a_browser_ENCODEHT002255843_path.png
# Saving transcript path graph for ENCODEHT002255848 as figures/scn1a_browser_ENCODEHT002255848_path.png
# Saving transcript path graph for ENCODEHT002766616 as figures/scn1a_browser_ENCODEHT002766616_path.png
# Saving transcript path graph for ENCODEHT002766620 as figures/scn1a_browser_ENCODEHT002766620_path.png
# Saving transcript path graph for ENCODEHT003171081 as figures/scn1a_browser_ENCODEHT003171081_path.png
# Saving transcript path graph for ENCODEHT003171082 as figures/scn1a_browser_ENCODEHT003171082_path.png
# Saving transcript path graph for ENCODEHT003171085 as figures/scn1a_browser_ENCODEHT003171085_path.png
# Saving transcript path graph for ENCODEHT003171090 as figures/scn1a_browser_ENCODEHT003171090_path.png
# Saving transcript path graph for ENCODEHT003171095 as figures/scn1a_browser_ENCODEHT003171095_path.png
# Saving transcript path graph for ENCODEHT003171096 as figures/scn1a_browser_ENCODEHT003171096_path.png
# Saving transcript path graph for ENCODEHT003520054 as figures/scn1a_browser_ENCODEHT003520054_path.png
# Saving transcript path graph for ENCODEHT003520055 as figures/scn1a_browser_ENCODEHT003520055_path.png
# Saving transcript path graph for ENCODEHT003520056 as figures/scn1a_browser_ENCODEHT003520056_path.png
# Saving transcript path graph for ENCODEHT003520058 as figures/scn1a_browser_ENCODEHT003520058_path.png
# Saving transcript path graph for ENCODEHT003658240 as figures/scn1a_browser_ENCODEHT003658240_path.png
# Saving transcript path graph for ENCODEHT004176606 as figures/scn1a_browser_ENCODEHT004176606_path.png
# Saving transcript path graph for ENCODEHT004176608 as figures/scn1a_browser_ENCODEHT004176608_path.png
# Saving transcript path graph for ENCODEHT004176609 as figures/scn1a_browser_ENCODEHT004176609_path.png
# Saving transcript path graph for ENCODEHT004176611 as figures/scn1a_browser_ENCODEHT004176611_path.png
# Saving transcript path graph for ENCODEHT004176616 as figures/scn1a_browser_ENCODEHT004176616_path.png
# Saving transcript path graph for ENCODEHT004176621 as figures/scn1a_browser_ENCODEHT004176621_path.png
# Saving transcript path graph for ENCODEHT004176623 as figures/scn1a_browser_ENCODEHT004176623_path.png
# Saving transcript path graph for ENCODEHT004176627 as figures/scn1a_browser_ENCODEHT004176627_path.png
# Saving transcript path graph for ENCODEHT004176628 as figures/scn1a_browser_ENCODEHT004176628_path.png
# Saving transcript path graph for ENCODEHT004769722 as figures/scn1a_browser_ENCODEHT004769722_path.png
# Saving transcript path graph for ENCODEHT004769724 as figures/scn1a_browser_ENCODEHT004769724_path.png
# Saving transcript path graph for ENCODEHT004769725 as figures/scn1a_browser_ENCODEHT004769725_path.png
# Saving transcript path graph for ENCODEHT004769729 as figures/scn1a_browser_ENCODEHT004769729_path.png
# Saving transcript path graph for ENCODEHT004769731 as figures/scn1a_browser_ENCODEHT004769731_path.png
# Saving transcript path graph for ENCODEHT004769733 as figures/scn1a_browser_ENCODEHT004769733_path.png
# Saving transcript path graph for ENCODEHT004769734 as figures/scn1a_browser_ENCODEHT004769734_path.png
# Saving transcript path graph for ENCODEHT005459484 as figures/scn1a_browser_ENCODEHT005459484_path.png
# Saving transcript path graph for ENCODEHT005459494 as figures/scn1a_browser_ENCODEHT005459494_path.png
# Saving transcript path graph for ENCODEHT005459495 as figures/scn1a_browser_ENCODEHT005459495_path.png
# Saving transcript path graph for ENCODEHT005459500 as figures/scn1a_browser_ENCODEHT005459500_path.png
# Saving transcript path graph for ENCODEHT005459502 as figures/scn1a_browser_ENCODEHT005459502_path.png
# Saving transcript path graph for ENCODEHT005459505 as figures/scn1a_browser_ENCODEHT005459505_path.png
# Saving transcript path graph for ENCODEHT005459507 as figures/scn1a_browser_ENCODEHT005459507_path.png
# Saving transcript path graph for ENCODEHT005459510 as figures/scn1a_browser_ENCODEHT005459510_path.png
# Saving transcript path graph for ENCODEHT005459517 as figures/scn1a_browser_ENCODEHT005459517_path.png
# Saving transcript path graph for ENCODEHT005459521 as figures/scn1a_browser_ENCODEHT005459521_path.png
# Saving transcript path graph for ENCODEHT005459522 as figures/scn1a_browser_ENCODEHT005459522_path.png
# Saving transcript path graph for ENCODEHT005459525 as figures/scn1a_browser_ENCODEHT005459525_path.png
# Saving transcript path graph for ENCODEHT005459529 as figures/scn1a_browser_ENCODEHT005459529_path.png
# Saving transcript path graph for ENCODEHT005459534 as figures/scn1a_browser_ENCODEHT005459534_path.png
# Saving transcript path graph for ENCODEHT005459539 as figures/scn1a_browser_ENCODEHT005459539_path.png
# Saving transcript path graph for ENCODEHT005459540 as figures/scn1a_browser_ENCODEHT005459540_path.png
# Saving transcript path graph for ENCODEHT005459543 as figures/scn1a_browser_ENCODEHT005459543_path.png
# Saving transcript path graph for ENCODEHT005459546 as figures/scn1a_browser_ENCODEHT005459546_path.png
# Saving transcript path graph for ENCODEHT005459547 as figures/scn1a_browser_ENCODEHT005459547_path.png
# Saving transcript path graph for ENCODEHT005459549 as figures/scn1a_browser_ENCODEHT005459549_path.png
# Saving transcript path graph for ENCODEHT005459567 as figures/scn1a_browser_ENCODEHT005459567_path.png
# Saving transcript path graph for ENCODEHT005459571 as figures/scn1a_browser_ENCODEHT005459571_path.png
# Saving transcript path graph for ENCODEHT005459587 as figures/scn1a_browser_ENCODEHT005459587_path.png
# Saving transcript path graph for ENST00000303395.8 as figures/scn1a_browser_ENST00000303395.8_path.png
# Saving transcript path graph for ENST00000375405.7 as figures/scn1a_browser_ENST00000375405.7_path.png
# Saving transcript path graph for ENST00000409050.1 as figures/scn1a_browser_ENST00000409050.1_path.png
# Saving transcript path graph for ENST00000423058.6 as figures/scn1a_browser_ENST00000423058.6_path.png
# Saving transcript path graph for ENST00000473295.2 as figures/scn1a_browser_ENST00000473295.2_path.png
# Saving transcript path graph for ENST00000491429.1 as figures/scn1a_browser_ENST00000491429.1_path.png
# Saving transcript path graph for ENST00000507401.2 as figures/scn1a_browser_ENST00000507401.2_path.png
# Saving transcript path graph for ENST00000625916.1 as figures/scn1a_browser_ENST00000625916.1_path.png
# Saving transcript path graph for ENST00000635750.1 as figures/scn1a_browser_ENST00000635750.1_path.png
# Saving transcript path graph for ENST00000635776.1 as figures/scn1a_browser_ENST00000635776.1_path.png
# Saving transcript path graph for ENST00000635893.1 as figures/scn1a_browser_ENST00000635893.1_path.png
# Saving transcript path graph for ENST00000636194.1 as figures/scn1a_browser_ENST00000636194.1_path.png
# Saving transcript path graph for ENST00000636759.1 as figures/scn1a_browser_ENST00000636759.1_path.png
# Saving transcript path graph for ENST00000637038.1 as figures/scn1a_browser_ENST00000637038.1_path.png
# Saving transcript path graph for ENST00000637285.2 as figures/scn1a_browser_ENST00000637285.2_path.png
# Saving transcript path graph for ENST00000637968.1 as figures/scn1a_browser_ENST00000637968.1_path.png
# Saving transcript path graph for ENST00000637988.1 as figures/scn1a_browser_ENST00000637988.1_path.png
# Saving transcript path graph for ENST00000640036.1 as figures/scn1a_browser_ENST00000640036.1_path.png
# Saving transcript path graph for ENST00000641575.1 as figures/scn1a_browser_ENST00000641575.1_path.png
# Saving transcript path graph for ENST00000641603.1 as figures/scn1a_browser_ENST00000641603.1_path.png
# Saving transcript path graph for ENST00000641996.1 as figures/scn1a_browser_ENST00000641996.1_path.png
# Saving transcript path graph for ENST00000642141.1 as figures/scn1a_browser_ENST00000642141.1_path.png
