# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
df = pd.read_csv('../../lr_bulk/talon/human_talon_abundance.tsv', sep='\t')
df = get_tpm_table(df, sample='tissue', how='gene', save=True)
# Out:
# 39285

# %%
top_genes = pd.DataFrame()
for c in df.columns:
    df = df.sort_values(by=c, ascending=False)
#     print(df.head())
    temp = pd.DataFrame(df.iloc[:10, :].copy(deep=True).index.to_list(), 
                        columns=[c])
    top_genes = pd.concat([top_genes, temp], axis=1)

# %%
top_genes.head()
# Out:
#       adrenal_gland_1     adrenal_gland_3     adrenal_gland_2  \
# 0   ENSG00000148795.6   ENSG00000148795.6   ENSG00000148795.6
# 1  ENSG00000147465.11  ENSG00000087086.14  ENSG00000147465.11
# 2  ENSG00000087086.14  ENSG00000167996.15  ENSG00000160882.11
# 3  ENSG00000167996.15  ENSG00000156508.17   ENSG00000231852.7
# 4  ENSG00000085662.13  ENSG00000100604.12   ENSG00000203859.9
#
#               aorta_1             aorta_2    cardiac_septum_1  \
# 0  ENSG00000026025.15   ENSG00000278996.1  ENSG00000175084.11
# 1  ENSG00000075624.14  ENSG00000148180.19  ENSG00000111245.14
# 2  ENSG00000149591.16   ENSG00000280441.2  ENSG00000175206.10
# 3  ENSG00000107796.13   ENSG00000281383.1  ENSG00000092054.12
# 4  ENSG00000156508.17   ENSG00000251562.8  ENSG00000143632.14
#
#   heart_left_ventricle_4 heart_left_ventricle_1 heart_left_ventricle_3  \
# 0     ENSG00000175084.11     ENSG00000111245.14     ENSG00000111245.14
# 1     ENSG00000111245.14     ENSG00000151729.10     ENSG00000175084.11
# 2     ENSG00000143632.14     ENSG00000140416.20     ENSG00000092054.12
# 3     ENSG00000140416.20      ENSG00000114854.7     ENSG00000151729.10
# 4     ENSG00000151729.10      ENSG00000104879.4      ENSG00000104879.4
#
#   heart_left_ventricle_2  ...      psoas_muscle_1 right_cardiac_atrium_1  \
# 0     ENSG00000175084.11  ...   ENSG00000104879.4     ENSG00000197616.11
# 1     ENSG00000143632.14  ...  ENSG00000175084.11     ENSG00000175206.10
# 2     ENSG00000151729.10  ...  ENSG00000143632.14     ENSG00000175084.11
# 3      ENSG00000104879.4  ...  ENSG00000150991.14      ENSG00000104879.4
# 4     ENSG00000140416.20  ...  ENSG00000111640.14     ENSG00000050165.17
#
#   right_cardiac_atrium_3 right_cardiac_atrium_4 right_cardiac_atrium_2  \
# 0     ENSG00000175084.11     ENSG00000175206.10     ENSG00000175206.10
# 1     ENSG00000197616.11     ENSG00000175084.11     ENSG00000175084.11
# 2     ENSG00000175206.10     ENSG00000197616.11     ENSG00000197616.11
# 3      ENSG00000104879.4      ENSG00000104879.4      ENSG00000104879.4
# 4     ENSG00000151729.10     ENSG00000050165.17     ENSG00000050165.17
#
#   right_lobe_of_liver_1 right_lobe_of_liver_2  \
# 0    ENSG00000087086.14    ENSG00000163631.16
# 1    ENSG00000163631.16    ENSG00000171560.14
# 2     ENSG00000257017.8    ENSG00000091513.15
# 3    ENSG00000173432.11    ENSG00000197249.13
# 4    ENSG00000138207.13     ENSG00000243649.8
#
#   right_ventricle_myocardium_inferior_1 right_ventricle_myocardium_superior_1  \
# 0                    ENSG00000175084.11                    ENSG00000175084.11
# 1                    ENSG00000092054.12                     ENSG00000104879.4
# 2                    ENSG00000111245.14                    ENSG00000151729.10
# 3                    ENSG00000140416.20                    ENSG00000092054.12
# 4                     ENSG00000104879.4                    ENSG00000140416.20
#
#   upper_lobe_of_right_lung_1
# 0         ENSG00000122852.14
# 1         ENSG00000168484.12
# 2         ENSG00000168878.16
# 3         ENSG00000185303.16
# 4         ENSG00000087086.14
#
# [5 rows x 42 columns]

# %%
top_genes.to_csv('tissue_top_10_genes.tsv', sep='\t')
