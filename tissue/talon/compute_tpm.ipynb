# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
df = pd.read_csv('../../lr_bulk/talon/human_talon_abundance.tsv', sep='\t')
tpm_df = get_tpm_table(df, sample='tissue', how='gene', save=True)
# Out:
# 39285

# %%
temp = df[['annot_gene_id', 'annot_gene_name']].drop_duplicates()
tpm_df = tpm_df.merge(temp, how='left', 
                      left_index=True, right_on='annot_gene_id')
tpm_df.set_index('annot_gene_name', inplace=True)
tpm_df.drop('annot_gene_id', axis=1, inplace=True)

# %%
top_genes = pd.DataFrame()
for c in tpm_df.columns:
    tpm_df = tpm_df.sort_values(by=c, ascending=False)
#     print(df.head())
    temp = pd.DataFrame(tpm_df.iloc[:10, :].copy(deep=True).index.to_list(), 
                        columns=[c])
    top_genes = pd.concat([top_genes, temp], axis=1)

# %%
top_genes.head()
# Out:
#   adrenal_gland_1_1 adrenal_gland_3_1 adrenal_gland_2_1 aorta_1_1   aorta_2_1  \
# 0           CYP17A1           CYP17A1           CYP17A1       VIM  FP671120.1
# 1              STAR               FTL              STAR      ACTB         GSN
# 2               FTL              FTH1           CYP11B1     TAGLN  FP236383.1
# 3              FTH1            EEF1A1           CYP21A2     ACTA2  FP671120.4
# 4            AKR1B1              CHGA            HSD3B2    EEF1A1      MALAT1
#
#   cardiac_septum_1_1 heart_left_ventricle_4_1 heart_left_ventricle_1_1  \
# 0                DES                      DES                     MYL2
# 1               MYL2                     MYL2                  SLC25A4
# 2               NPPA                    ACTA1                     TPM1
# 3               MYH7                     TPM1                    TNNC1
# 4              ACTA1                  SLC25A4                      CKM
#
#   heart_left_ventricle_3_1 heart_left_ventricle_2_1  ... psoas_muscle_1_1  \
# 0                     MYL2                      DES  ...              CKM
# 1                      DES                    ACTA1  ...              DES
# 2                     MYH7                  SLC25A4  ...            ACTA1
# 3                  SLC25A4                      CKM  ...              UBC
# 4                      CKM                     TPM1  ...            GAPDH
#
#   right_cardiac_atrium_1_1 right_cardiac_atrium_3_1 right_cardiac_atrium_4_1  \
# 0                     MYH6                      DES                     NPPA
# 1                     NPPA                     MYH6                      DES
# 2                      DES                     NPPA                     MYH6
# 3                      CKM                      CKM                      CKM
# 4                     DKK3                  SLC25A4                     DKK3
#
#   right_cardiac_atrium_2_1 right_lobe_of_liver_1_1 right_lobe_of_liver_2_1  \
# 0                     NPPA                     FTL                     ALB
# 1                      DES                     ALB                     FGA
# 2                     MYH6                      HP                      TF
# 3                      CKM                    SAA1                SERPINA1
# 4                     DKK3                    RBP4                     CFB
#
#   right_ventricle_myocardium_inferior_1_1  \
# 0                                     DES
# 1                                    MYH7
# 2                                    MYL2
# 3                                    TPM1
# 4                                     CKM
#
#   right_ventricle_myocardium_superior_1_1 upper_lobe_of_right_lung_1_1
# 0                                     DES                       SFTPA1
# 1                                     CKM                        SFTPC
# 2                                 SLC25A4                        SFTPB
# 3                                    MYH7                       SFTPA2
# 4                                    TPM1                          FTL
#
# [5 rows x 42 columns]

# %%
top_genes.to_csv('tissue_top_10_genes.tsv', sep='\t')
