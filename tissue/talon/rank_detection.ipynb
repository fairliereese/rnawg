# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os

p = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(p)

from scripts.utils import *
from scripts.plotting import *

# %%
df = pd.read_csv('../../lr_bulk/talon/human_talon_abundance.tsv', sep='\t')
min_df, max_df = plot_ranked_biosamp(df,
                    sample='tissue',
                    how='gene', 
                    nov='Known',
                    opref='figures/')
# Out:
# Found 10 distinct tissues

# %%
min_df
# Out:
#     n_cumulative  rank       celltype
# 0              0     1            n/a
# 1          26625     2          heart
# 2          29564     3           lung
# 3          31135     4        vessels
# 4          31769     5          colon
# 5          32253     6          ovary
# 6          32577     7  adrenal gland
# 7          32801     8         kidney
# 8          33002     9        adipose
# 9          33148    10          liver
# 10         33256    11         muscle

# %%
df = pd.read_csv('../../lr_bulk/talon/human_talon_abundance_filtered.tsv', sep='\t')
_, _ = plot_ranked_biosamp(df,
                    sample='tissue',
                    how='iso', 
                    nov='Known',
                    opref='figures/')

# %%
df = pd.read_csv('../../lr_bulk/talon/human_talon_abundance_filtered.tsv', sep='\t')
_, _ = plot_ranked_biosamp(df,
                    sample='tissue',
                    how='iso', 
                    nov='NIC',
                    opref='figures/')

# %%
df = pd.read_csv('../../lr_bulk/talon/human_talon_abundance_filtered.tsv', sep='\t')
_, _ = plot_ranked_biosamp(df,
                    sample='tissue',
                    how='iso', 
                    nov='NNC',
                    opref='figures/')
